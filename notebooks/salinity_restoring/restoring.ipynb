# %% [markdown]
# # Analyse impact of salinity restoring relative to meltwater perturbation

# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc
import cartopy.crs as ccrs
import xarray as xr
import cmocean.cm as cmocean
import glob
import matplotlib.path as mpath
import matplotlib.colors as col
from gsw import SA_from_SP, p_from_z

import logging
logging.captureWarnings(True)
logging.getLogger('py.warnings').setLevel(logging.ERROR)

from dask.distributed import Client

figdir = '/g/data/v45/akm157/figures/IAF_meltwater/'

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:43825' processes=7 threads=28, memory=125.20 GiB>

# %%
master_session = cc.database.create_session()

control = '01deg_jra55v140_iaf_cycle4'
iaf_melt = '01deg_jra55v140_iaf_cycle4_MWpert'

start_time='1979-01-01'
end_time='2018-12-31'

lat_slice  = slice(-80,-59)

# %%
# topography data for plotting:
ht = cc.querying.getvar(control,'ht' , master_session,n=1).sel(yt_ocean=lat_slice)
land_mask = np.squeeze(ht.values)*0
land_mask[np.isnan(land_mask)] = 1
land_mask = np.where(land_mask==1,land_mask,np.nan)
land_mask_masked = np.ma.masked_where((land_mask==0),land_mask)
# make land go all the way to -90S:
#land_mask_lat = ht.yt_ocean.values
#land_mask_lat[0] = -90

fontsize=15

# %% [markdown]
# ## Time series of restoring over shelf:

# %%
# shelf masking:
contour_file = np.load('/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz')
shelf_mask = contour_file['contour_masked_above']
yt_ocean = contour_file['yt_ocean']
xt_ocean = contour_file['xt_ocean']
# Mask values that are non-zero
shelf_mask[np.where(shelf_mask!=0)] = np.nan
shelf_mask = shelf_mask+1
shelf_mask = xr.DataArray(shelf_mask, coords = [('yt_ocean', yt_ocean), ('xt_ocean', xt_ocean)])

area_t = cc.querying.getvar(control, 'area_t', master_session,n=1).sel(yt_ocean=lat_slice)
area_t = (area_t*shelf_mask).load()
area_sum = area_t.sum(dim={'xt_ocean','yt_ocean'}).load()

# %%
# stuff needed for absolute salinity conversion:
st_ocean = cc.querying.getvar(control,'st_ocean',master_session,n=1).load()
geolon_t = cc.querying.getvar(control,'geolon_t',master_session, n=1).sel(yt_ocean=lat_slice).load()
geolat_t = cc.querying.getvar(control,'geolat_t',master_session, n=1).sel(yt_ocean=lat_slice).load()
depth_tile = -(geolat_t*0+1)*st_ocean[0].values
pressure = xr.DataArray(p_from_z(depth_tile,geolat_t), coords = [yt_ocean, xt_ocean], dims = ['yt_ocean', 'xt_ocean'], 
                        name = 'pressure', attrs = {'units':'dbar'})

# %%
SSS_prac = cc.querying.getvar(control, 'salt', master_session, frequency='1 monthly',start_time=start_time, end_time=end_time)
SSS_prac = SSS_prac.sel(time=slice(start_time,end_time)).sel(yt_ocean=lat_slice).sel(st_ocean=0,method='nearest')
# convert units to absolute salinity:
SSS_con = xr.DataArray(SA_from_SP(SSS_prac,pressure,geolon_t,geolat_t), coords = [SSS_prac.time, SSS_prac.yt_ocean, SSS_prac.xt_ocean], 
                       dims = ['time','yt_ocean', 'xt_ocean'], name = 'sea surface salinity', 
                       attrs = {'units':'Absolute Salinity (g/kg)'})

restoring_con = cc.querying.getvar(control, 'sfc_salt_flux_restore', master_session, frequency='1 monthly',
                                   start_time=start_time, end_time=end_time)
restoring_con = restoring_con.sel(time=slice(start_time,end_time)).sel(yt_ocean=lat_slice)
# need factor of 1000, because salt flux is in (kg of salt)/m^2/s, but SSS is in (g salt)/(kg of water)
restoring_con = restoring_con*1000/SSS_con

# restrict to shelf and integrate over area:
restoring_con = (restoring_con*area_t).sum('xt_ocean').sum('yt_ocean')/area_sum
restoring_con = restoring_con.load()
# Out:
# 2022-09-15 11:10:48,864 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,030 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,194 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,320 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,369 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,412 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,595 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,782 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,792 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,816 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,824 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:49,884 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:50,067 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:50,136 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:50,274 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:50,327 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:50,349 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:50,354 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-15 11:10:50,441 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:00,215 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:00,216 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:00,497 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:01,576 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:01,860 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:01,927 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:03,704 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:03,761 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:06,684 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:08,829 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:12,087 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:12,109 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:12,446 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:13,996 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:20,125 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:20,872 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:21,443 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:24,871 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:26,047 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:41,462 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:43,204 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:43,333 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:43,625 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:44,103 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:45,029 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:45,973 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:50,884 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:51,060 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:54,983 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:55,827 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:12:59,709 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:13:05,135 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2022-09-15 11:13:10,279 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-09-15 11:13:26,989 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)

# %%
restoring_con.plot()

# %%
SSS_prac = cc.querying.getvar(iaf_melt, 'salt', master_session, frequency='1 monthly',start_time=start_time, end_time=end_time)
SSS_prac = SSS_prac.sel(time=slice(start_time,end_time)).sel(yt_ocean=lat_slice).sel(st_ocean=0,method='nearest')
# convert units to absolute salinity:
SSS_melt = xr.DataArray(SA_from_SP(SSS_prac,pressure,geolon_t,geolat_t), coords = [SSS_prac.time, SSS_prac.yt_ocean, SSS_prac.xt_ocean], 
                       dims = ['time','yt_ocean', 'xt_ocean'], name = 'sea surface salinity', 
                       attrs = {'units':'Absolute Salinity (g/kg)'})

restoring_melt = cc.querying.getvar(iaf_melt, 'sfc_salt_flux_restore', master_session, frequency='1 monthly',
                                   start_time=start_time, end_time=end_time)
restoring_melt = restoring_melt.sel(time=slice(start_time,end_time)).sel(yt_ocean=lat_slice)
# need factor of 1000, because salt flux is in (kg of salt)/m^2/s, but SSS is in (g salt)/(kg of water)
restoring_melt = restoring_melt*1000/SSS_melt

# restrict to shelf and integrate over area:
restoring_melt = (restoring_melt*area_t).sum('xt_ocean').sum('yt_ocean')/area_sum
restoring_melt = restoring_melt.load()

# %%
# compare to runoff:

runoff_con = cc.querying.getvar(control, 'runoff', master_session, frequency='1 monthly',
                                   start_time=start_time, end_time=end_time)
runoff_con = runoff_con.sel(time=slice(start_time,end_time)).sel(yt_ocean=lat_slice)
# restrict to shelf and integrate over area:
runoff_con = (runoff_con*area_t).sum('xt_ocean').sum('yt_ocean')/area_sum
runoff_con = runoff_con.load()

runoff_melt = cc.querying.getvar(iaf_melt, 'runoff', master_session, frequency='1 monthly',
                                   start_time=start_time, end_time=end_time)
runoff_melt = runoff_melt.sel(time=slice(start_time,end_time)).sel(yt_ocean=lat_slice)
# restrict to shelf and integrate over area:
runoff_melt = (runoff_melt*area_t).sum('xt_ocean').sum('yt_ocean')/area_sum
runoff_melt = runoff_melt.load()

# %%
# units of both should be (kg of water)/m^2/s averaged over the shelf:

plt.figure(figsize=(14,7))
(runoff_melt - runoff_con).plot(label='runoff perturbation')
((runoff_melt - runoff_con)-(restoring_melt - restoring_con)).plot(label='runoff minus restoring change')
plt.legend()
plt.ylabel('Freshwater flux equivalent ((kg of water)/m^2/s)')
plt.title('Runoff and restoring integrated over shelf')
plt.ylim(0,2.1e-6)
# Out:
# (0.0, 2.1e-06)

# %%
((runoff_melt - runoff_con)-(restoring_melt - restoring_con))[-1]/(runoff_melt - runoff_con)[-1]
# Out:
# <xarray.DataArray ()>
# array(0.68835659)
# Coordinates:
#     time     datetime64[ns] 2018-12-16T12:00:00
